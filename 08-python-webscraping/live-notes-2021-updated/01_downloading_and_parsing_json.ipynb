# %%
import requests

response = requests.get("https://www.covid19.admin.ch/api/data/context")

# %%
type(response)
# Out:
# requests.models.Response

# %%
response.request.headers
# Out:
# {'User-Agent': 'python-requests/2.28.1', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
response.status_code
# Out:
# 200

# %%
response.headers
# Out:
# {'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'max-age=0,s-maxage=31536000,must-revalidate', 'Content-Security-Policy': "default-src 'none'; style-src 'self'; frame-ancestors 'none'; form-action 'none'", 'Date': 'Tue, 30 Aug 2022 13:30:48 GMT', 'Feature-Policy': "microphone 'none'; geolocation 'none'", 'Permissions-Policy': 'microphone=(), geolocation=()', 'Referrer-Policy': 'strict-origin-when-cross-origin', 'Strict-Transport-Security': 'max-age=16070400; includeSubDomains', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'sameorigin', 'X-Vcap-Request-Id': '3d229b5d-328a-46fa-5f92-fb7bf1f02622', 'X-Xss-Protection': '1; mode=block', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'X-Cache': 'Hit from cloudfront', 'Via': '1.1 df327bd0c8709a81ade8602ac9ef16e0.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'FRA56-P7', 'X-Amz-Cf-Id': 'pi9uWsqq3xNTgTUqrmIiGAtnCZ0Rdey-jkggkbzQtJoYM5h5e5YpKw==', 'Age': '97559'}

# %%
data = response.json()

# %%
type(data)
# Out:
# dict

# %%
data['sources']
# Out:
# {'comment': 'OpenData DCAT-AP-CH metadata is now available as well. See below for details.',
#  'opendata': {'standard': 'DCAT-AP-CH',
#   'catalog': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/opendata/catalog.xml',
#   'opendataSwissDataset': 'https://opendata.swiss/en/dataset/covid-19-schweiz'},
#  'schema': {'version': '0.24.0',
#   'jsonSchema': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/sources.schema.json'},
#  'readme': 'https://www.covid19.admin.ch/api/data/documentation/',
#  'zip': {'json': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/downloads/sources-json.zip',
#   'csv': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/downloads/sources-csv.zip'},
#  'individual': {'json': {'daily': {'cases': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_geoRegion.json',
#     'casesVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_vaccpersons.json',
#     'hosp': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_geoRegion.json',
#     'hospVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_vaccpersons.json',
#     'death': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Death_geoRegion.json',
#     'deathVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Death_vaccpersons.json',
#     'test': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Test_geoRegion_all.json',
#     'testPcrAntigen': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Test_geoRegion_PCR_Antigen.json',
#     'hospCapacity': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19HospCapacity_geoRegion.json',
#     'hospCapacityCertStatus': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19HospCapacity_geoRegion_certStatus.json',
#     're': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Re_geoRegion.json',
#     'intCases': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19IntCases.json',
#     'virusVariantsWgs': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Variants_wgs.json',
#     'covidCertificates': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Certificates.json'},
#    'weekly': {'byAge': {'cases': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_geoRegion_AKL10_w.json',
#      'casesVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_vaccpersons_AKL10_w.json',
#      'hosp': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_geoRegion_AKL10_w.json',
#      'hospReason': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_reason_AKL10_w.json',
#      'hospVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_vaccpersons_AKL10_w.json',
#      'death': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Death_geoRegion_AKL10_w.json',
#      'deathVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Death_vaccpersons_AKL10_w.json',
#      'test': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Test_geoRegion_AKL10_w.json'},
#     'bySex': {'cases': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_geoRegion_sex_w.json',
#      'casesVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_vaccpersons_sex_w.json',
#      'hosp': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_geoRegion_sex_w.json',
#      'hospVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_vaccpersons_sex_w.json',
#      'death': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Death_geoRegion_sex_w.json',
#      'deathVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Death_vaccpersons_sex_w.json',
#      'test': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Test_geoRegion_sex_w.json'},
#     'default': {'cases': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_geoRegion_w.json',
#      'hosp': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_geoRegion_w.json',
#      'death': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Death_geoRegion_w.json',
#      'test': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Test_geoRegion_w.json',
#      'testPcrAntigen': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Test_geoRegion_PCR_Antigen_w.json',
#      'hospCapacity': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19HospCapacity_geoRegion_w.json'}},
#    'extraGeoUnits': {'cases': {'daily': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_extraGeoRegions_d.json',
#      'biweekly': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_extraGeoRegions_14d.json'}},
#    'wasteWater': {'viralLoad': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Wastewater_vl.json',
#     'viralLoadOverview': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Wastewater_vlOverview.json'},
#    'weeklyReportText': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19WeeklyReportText.json',
#    'dailyReport': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19EvalTextDaily.json',
#    'contactTracing': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19QuarantineIsolation_geoRegion_d.json',
#    'intQua': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19IntQua.json',
#    'vaccDosesDelivered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesDelivered.json',
#    'vaccDosesContingent': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesContingent.json',
#    'vaccDosesAdministered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesAdministered.json',
#    'vaccPersonsV2': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccPersons_v2.json',
#    'vaccSymptoms': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccSymptoms.json',
#    'weeklyVacc': {'byAge': {'vaccDosesAdministered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesAdministered_AKL10_w.json',
#      'vaccPersonsV2': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccPersons_AKL10_w_v2.json'},
#     'bySex': {'vaccDosesAdministered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesAdministered_sex_w.json',
#      'vaccPersonsV2': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccPersons_sex_w_v2.json'},
#     'byIndication': {'vaccDosesAdministered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesAdministered_indication_w.json',
#      'fullyVaccPersonsV2': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19FullyVaccPersons_indication_w_v2.json'},
#     'byLocation': {'vaccDosesAdministered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesAdministered_location_w.json'},
#     'byVaccine': {'vaccDosesDelivered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesDelivered_vaccine.json',
#      'vaccDosesAdministered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19AdministeredDoses_vaccine.json',
#      'vaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccPersons_vaccine.json'},
#     'byAgeAndVaccine': {'vaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccPersons_AKL10_vaccine_w.json'}},
#    'rawData': {'dailyEpi': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19EpiRawData_d.json',
#     'dailyCasesAgeRange': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19CasesRawData_AKL10_d.json',
#     'weeklyEpiAgeRangeSex': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19EpiRawData_AKL10_sex_w.json',
#     'populationAgeRangeSex': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/PopulationAgeRangeSexData.json'}},
#   'csv': {'daily': {'cases': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_geoRegion.csv',
#     'casesVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_vaccpersons.csv',
#     'hosp': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_geoRegion.csv',
#     'hospVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_vaccpersons.csv',
#     'death': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Death_geoRegion.csv',
#     'deathVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Death_vaccpersons.csv',
#     'test': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Test_geoRegion_all.csv',
#     'testPcrAntigen': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Test_geoRegion_PCR_Antigen.csv',
#     'hospCapacity': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19HospCapacity_geoRegion.csv',
#     'hospCapacityCertStatus': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19HospCapacity_geoRegion_certStatus.csv',
#     're': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Re_geoRegion.csv',
#     'intCases': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19IntCases.csv',
#     'virusVariantsWgs': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Variants_wgs.csv',
#     'covidCertificates': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Certificates.csv'},
#    'weekly': {'byAge': {'cases': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_geoRegion_AKL10_w.csv',
#      'casesVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_vaccpersons_AKL10_w.csv',
#      'hosp': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_geoRegion_AKL10_w.csv',
#      'hospReason': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_reason_AKL10_w.csv',
#      'hospVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_vaccpersons_AKL10_w.csv',
#      'death': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Death_geoRegion_AKL10_w.csv',
#      'deathVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Death_vaccpersons_AKL10_w.csv',
#      'test': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Test_geoRegion_AKL10_w.csv'},
#     'bySex': {'cases': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_geoRegion_sex_w.csv',
#      'casesVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_vaccpersons_sex_w.csv',
#      'hosp': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_geoRegion_sex_w.csv',
#      'hospVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_vaccpersons_sex_w.csv',
#      'death': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Death_geoRegion_sex_w.csv',
#      'deathVaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Death_vaccpersons_sex_w.csv',
#      'test': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Test_geoRegion_sex_w.csv'},
#     'default': {'cases': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_geoRegion_w.csv',
#      'hosp': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Hosp_geoRegion_w.csv',
#      'death': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Death_geoRegion_w.csv',
#      'test': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Test_geoRegion_w.csv',
#      'testPcrAntigen': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Test_geoRegion_PCR_Antigen_w.csv',
#      'hospCapacity': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19HospCapacity_geoRegion_w.csv'}},
#    'extraGeoUnits': {'cases': {'daily': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_extraGeoRegions_d.csv',
#      'biweekly': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Cases_extraGeoRegions_14d.csv'}},
#    'wasteWater': {'viralLoad': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Wastewater_vl.csv',
#     'viralLoadOverview': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19Wastewater_vlOverview.csv'},
#    'weeklyReportText': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19WeeklyReportText.csv',
#    'dailyReport': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19EvalTextDaily.csv',
#    'contactTracing': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19QuarantineIsolation_geoRegion_d.csv',
#    'intQua': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19IntQua.csv',
#    'vaccDosesDelivered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesDelivered.csv',
#    'vaccDosesContingent': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesContingent.csv',
#    'vaccDosesAdministered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesAdministered.csv',
#    'vaccPersonsV2': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccPersons_v2.csv',
#    'vaccSymptoms': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccSymptoms.csv',
#    'weeklyVacc': {'byAge': {'vaccDosesAdministered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesAdministered_AKL10_w.csv',
#      'vaccPersonsV2': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccPersons_AKL10_w_v2.csv'},
#     'bySex': {'vaccDosesAdministered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesAdministered_sex_w.csv',
#      'vaccPersonsV2': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccPersons_sex_w_v2.csv'},
#     'byIndication': {'vaccDosesAdministered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesAdministered_indication_w.csv',
#      'fullyVaccPersonsV2': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19FullyVaccPersons_indication_w_v2.csv'},
#     'byLocation': {'vaccDosesAdministered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesAdministered_location_w.csv'},
#     'byVaccine': {'vaccDosesDelivered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccDosesDelivered_vaccine.csv',
#      'vaccDosesAdministered': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19AdministeredDoses_vaccine.csv',
#      'vaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccPersons_vaccine.csv'},
#     'byAgeAndVaccine': {'vaccPersons': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19VaccPersons_AKL10_vaccine_w.csv'}},
#    'rawData': {'dailyEpi': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19EpiRawData_d.csv',
#     'dailyCasesAgeRange': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19CasesRawData_AKL10_d.csv',
#     'weeklyEpiAgeRangeSex': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/COVID19EpiRawData_AKL10_sex_w.csv',
#     'populationAgeRangeSex': 'https://www.covid19.admin.ch/api/data/20220830-hbxz06tw/sources/PopulationAgeRangeSexData.csv'}}}}

# %%
response_2 = requests.get("https://www.covid19.admin.ch/api/data/20210908-icrm7h5q/sources/COVID19Cases_geoRegion.json")
response_2.status_code
# Out:
# 200

# %%
response_2.content[:1000]
# Out:
# b'[{"geoRegion":"CH","datum":"2020-02-24","entries":1,"sumTotal":1,"timeframe_7d":false,"offset_last7d":780900,"sumTotal_last7d":0,"timeframe_14d":false,"offset_last14d":763257,"sumTotal_last14d":0,"timeframe_28d":false,"offset_last28d":728769,"sumTotal_last28d":0,"timeframe_phase2":false,"offset_Phase2":30944,"sumTotal_Phase2":0,"timeframe_phase2b":false,"offset_Phase2b":52690,"sumTotal_Phase2b":0,"timeframe_phase3":false,"offset_Phase3":540911,"sumTotal_Phase3":0,"timeframe_vacc_info":false,"offset_vacc_info":515824,"sumTotal_vacc_info":0,"timeframe_all":true,"entries_diff_last_age":1,"pop":8606033,"inz_entries":0.01,"inzsumTotal":0.01,"type":"COVID19Cases","type_variant":"","version":"2021-09-08_07-52-17","datum_unit":"day","entries_letzter_stand":1,"entries_neu_gemeldet":0,"entries_diff_last":3543},{"geoRegion":"CH","datum":"2020-02-25","entries":1,"sumTotal":2,"timeframe_7d":false,"offset_last7d":780900,"sumTotal_last7d":0,"timeframe_14d":false,"offset_last14d":763257,"sumTotal_last'

# %%
data_2 = response_2.json()

# %%
type(data_2)
# Out:
# list

# %%
data_2[1]
# Out:
# {'geoRegion': 'CH',
#  'datum': '2020-02-25',
#  'entries': 1,
#  'sumTotal': 2,
#  'timeframe_7d': False,
#  'offset_last7d': 780900,
#  'sumTotal_last7d': 0,
#  'timeframe_14d': False,
#  'offset_last14d': 763257,
#  'sumTotal_last14d': 0,
#  'timeframe_28d': False,
#  'offset_last28d': 728769,
#  'sumTotal_last28d': 0,
#  'timeframe_phase2': False,
#  'offset_Phase2': 30944,
#  'sumTotal_Phase2': 0,
#  'timeframe_phase2b': False,
#  'offset_Phase2b': 52690,
#  'sumTotal_Phase2b': 0,
#  'timeframe_phase3': False,
#  'offset_Phase3': 540911,
#  'sumTotal_Phase3': 0,
#  'timeframe_vacc_info': False,
#  'offset_vacc_info': 515824,
#  'sumTotal_vacc_info': 0,
#  'timeframe_all': True,
#  'entries_diff_last_age': 1,
#  'pop': 8606033,
#  'inz_entries': 0.01,
#  'inzsumTotal': 0.02,
#  'type': 'COVID19Cases',
#  'type_variant': '',
#  'version': '2021-09-08_07-52-17',
#  'datum_unit': 'day',
#  'entries_letzter_stand': 1,
#  'entries_neu_gemeldet': 0,
#  'entries_diff_last': 3543}

# %%
import pandas as pd

# %%
df = pd.DataFrame(data_2)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#   geoRegion       datum  entries  sumTotal  timeframe_7d  offset_last7d  \
# 0        CH  2020-02-24        1         1         False         780900
# 1        CH  2020-02-25        1         2         False         780900
# 2        CH  2020-02-26       10        12         False         780900
# 3        CH  2020-02-27       10        22         False         780900
# 4        CH  2020-02-28       10        32         False         780900
# 5        CH  2020-02-29       13        45         False         780900
# 6        CH  2020-03-01       11        56         False         780900
# 7        CH  2020-03-02       30        86         False         780900
# 8        CH  2020-03-03       33       119         False         780900
# 9        CH  2020-03-04       61       180         False         780900
#
#    sumTotal_last7d  timeframe_14d  offset_last14d  sumTotal_last14d  ...  \
# 0                0          False          763257                 0  ...
# 1                0          False          763257                 0  ...
# 2                0          False          763257                 0  ...
# 3                0          False          763257                 0  ...
# 4                0          False          763257                 0  ...
# 5                0          False          763257                 0  ...
# 6                0          False          763257                 0  ...
# 7                0          False          763257                 0  ...
# 8                0          False          763257                 0  ...
# 9                0          False          763257                 0  ...
#
#    sumdelta7d  inzdelta7d  sum14d  inzsum14d  inzsumTotal_Phase2  \
# 0         NaN         NaN     NaN        NaN                 NaN
# 1         NaN         NaN     NaN        NaN                 NaN
# 2         NaN         NaN     NaN        NaN                 NaN
# 3         NaN         NaN     NaN        NaN                 NaN
# 4         NaN         NaN     NaN        NaN                 NaN
# 5         NaN         NaN     NaN        NaN                 NaN
# 6         NaN         NaN     NaN        NaN                 NaN
# 7        29.0        0.34     NaN        NaN                 NaN
# 8        32.0        0.37     NaN        NaN                 NaN
# 9        51.0        0.59     NaN        NaN                 NaN
#
#    inzsumTotal_Phase2b  inzsumTotal_Phase3  inzsumTotal_last28d  \
# 0                  NaN                 NaN                  NaN
# 1                  NaN                 NaN                  NaN
# 2                  NaN                 NaN                  NaN
# 3                  NaN                 NaN                  NaN
# 4                  NaN                 NaN                  NaN
# 5                  NaN                 NaN                  NaN
# 6                  NaN                 NaN                  NaN
# 7                  NaN                 NaN                  NaN
# 8                  NaN                 NaN                  NaN
# 9                  NaN                 NaN                  NaN
#
#    inzsumTotal_last14d  inzsumTotal_last7d
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
# 5                  NaN                 NaN
# 6                  NaN                 NaN
# 7                  NaN                 NaN
# 8                  NaN                 NaN
# 9                  NaN                 NaN
#
# [10 rows x 53 columns]

# %%
data_2[0].keys()
# Out:
# dict_keys(['geoRegion', 'datum', 'entries', 'sumTotal', 'timeframe_7d', 'offset_last7d', 'sumTotal_last7d', 'timeframe_14d', 'offset_last14d', 'sumTotal_last14d', 'timeframe_28d', 'offset_last28d', 'sumTotal_last28d', 'timeframe_phase2', 'offset_Phase2', 'sumTotal_Phase2', 'timeframe_phase2b', 'offset_Phase2b', 'sumTotal_Phase2b', 'timeframe_phase3', 'offset_Phase3', 'sumTotal_Phase3', 'timeframe_vacc_info', 'offset_vacc_info', 'sumTotal_vacc_info', 'timeframe_all', 'entries_diff_last_age', 'pop', 'inz_entries', 'inzsumTotal', 'type', 'type_variant', 'version', 'datum_unit', 'entries_letzter_stand', 'entries_neu_gemeldet', 'entries_diff_last'])
